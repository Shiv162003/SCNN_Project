# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("/content/Covid_data.xlsx")

# %%
df.head()
# Out:
#    Sr. No.       Sample No.   Location  Red (R.)  Green (G)  Blue (B)  \
# 0       1.0  26 (11/02/2022)  Rahatani    0.1662     0.2344    0.2900
# 1       NaN              NaN  Rahatani    0.1740     0.2359    0.2903
# 2       NaN              NaN  Rahatani    0.1710     0.2387    0.2899
# 3       NaN              NaN  Rahatani    0.1768     0.2374    0.2923
# 4       NaN              NaN  Rahatani    0.1749     0.2375    0.2908
#
#    White (W)  Conc. (%)    RT-PCR
# 0     0.1787     2.0469  Positive
# 1     0.1788     2.0625  Positive
# 2     0.1986     2.0938  Positive
# 3     0.1945     2.0781  Positive
# 4     0.1865     2.0781  Positive

# %%
df.isna().sum()
# Out:
# Sr. No.        305
# Sample No.     311
# Location        46
# Red (R.)        46
# Green (G)       46
# Blue (B)        46
# White (W)       46
# Conc. (%)       46
# RT-PCR          80
# dtype: int64

# %%
df = df.dropna(subset=['Location'])

# %%
df
# Out:
#      Sr. No.       Sample No.           Location  Red (R.)  Green (G)  \
# 0         1.0  26 (11/02/2022)          Rahatani   0.16620    0.23440
# 1         NaN              NaN          Rahatani   0.17400    0.23590
# 2         NaN              NaN          Rahatani   0.17100    0.23870
# 3         NaN              NaN          Rahatani   0.17680    0.23740
# 4         NaN              NaN          Rahatani   0.17490    0.23750
# ..        ...              ...               ...       ...        ...
# 352       NaN              NaN  Mahalunge, Baner   0.09670    0.11190
# 353       NaN              NaN  Mahalunge, Baner   0.09130    0.11340
# 354       NaN              NaN  Mahalunge, Baner   0.08930    0.11370
# 355       NaN              NaN  Mahalunge, Baner   0.08360    0.11200
# 356       NaN              NaN          Average=   0.08372    0.11254
#
#      Blue (B)  White (W)  Conc. (%)    RT-PCR
# 0     0.29000    0.17870    2.04690  Positive
# ...

# %%
df.isna().sum()
# Out:
# Sr. No.        259
# Sample No.     265
# Location         0
# Red (R.)         0
# Green (G)        0
# Blue (B)         0
# White (W)        0
# Conc. (%)        0
# RT-PCR          34
# dtype: int64

# %%
df['Location'] = df['Location'].replace('Average=', method='ffill')

# %%
df
# Out:
#      Sr. No.       Sample No.           Location  Red (R.)  Green (G)  \
# 0         1.0  26 (11/02/2022)          Rahatani   0.16620    0.23440
# 1         NaN              NaN          Rahatani   0.17400    0.23590
# 2         NaN              NaN          Rahatani   0.17100    0.23870
# 3         NaN              NaN          Rahatani   0.17680    0.23740
# 4         NaN              NaN          Rahatani   0.17490    0.23750
# ..        ...              ...               ...       ...        ...
# 352       NaN              NaN  Mahalunge, Baner   0.09670    0.11190
# 353       NaN              NaN  Mahalunge, Baner   0.09130    0.11340
# 354       NaN              NaN  Mahalunge, Baner   0.08930    0.11370
# 355       NaN              NaN  Mahalunge, Baner   0.08360    0.11200
# 356       NaN              NaN  Mahalunge, Baner   0.08372    0.11254
#
#      Blue (B)  White (W)  Conc. (%)    RT-PCR
# 0     0.29000    0.17870    2.04690  Positive
# ...

# %%
df['Location'].unique()
# Out:
# array(['Rahatani', 'Kalewadi', 'Pimpri', 'Dapodi',
#        'Dapodi (Harris Bridge)', 'Blank', 'Cuvette (Blank)',
#        'Kothrud (Sanjeevan Hospital)', 'kothrud (Bus stand)',
#        'Karve Road', 'warje', 'Shivaji Nagar (Chaturshringhi)',
#        'Shivaji Nagar', 'Aundh (Botanical Grarden)', 'Aundh',
#        'Someshwarwadi', 'Pashan', 'Baner (Balewadi)',
#        'Mahalunge (Baner) ', 'Yerwada (RTO office)',
#        'yerwada (burning ghat)', 'Dattawadi', 'Vitthalwadi',
#        'Vishrantwadi', 'Pimple Gurav', 'Chinchwad', 'Kasarwadi',
#        'Blank (cuvette)', 'Shivajinagar',
#        'Shivaji nagar (Chaturshringhi)', 'Kothrud (Sanjeevan hospital)',
#        'Kothrud (Karve Road)', 'Warje', 'Kothrud (Bus depot)',
#        'Blank (heat inactivated)', 'Blank Cuvette', 'Shivaji nagar',
#        'Kothrud (Shivaji nagar)', 'Warje ', 'Kothrud',
#        'Someshwarwadi 11.01 am', 'Aundh Botanical garden 11.25 am',
# ...

# %%
df
# Out:
#      Sr. No.       Sample No.           Location  Red (R.)  Green (G)  \
# 0         1.0  26 (11/02/2022)          Rahatani   0.16620    0.23440
# 1         NaN              NaN          Rahatani   0.17400    0.23590
# 2         NaN              NaN          Rahatani   0.17100    0.23870
# 3         NaN              NaN          Rahatani   0.17680    0.23740
# 4         NaN              NaN          Rahatani   0.17490    0.23750
# ..        ...              ...               ...       ...        ...
# 352       NaN              NaN  Mahalunge, Baner   0.09670    0.11190
# 353       NaN              NaN  Mahalunge, Baner   0.09130    0.11340
# 354       NaN              NaN  Mahalunge, Baner   0.08930    0.11370
# 355       NaN              NaN  Mahalunge, Baner   0.08360    0.11200
# 356       NaN              NaN  Mahalunge, Baner   0.08372    0.11254
#
#      Blue (B)  White (W)  Conc. (%)    RT-PCR
# 0     0.29000    0.17870    2.04690  Positive
# ...

# %%
# Remove rows where 'Location' is "Average="
df = df[df['Location'] != 'Average=']

# %%
df['Location'].unique()
# Out:
# array(['Rahatani', 'Kalewadi', 'Pimpri', 'Dapodi',
#        'Dapodi (Harris Bridge)', 'Blank', 'Cuvette (Blank)',
#        'Kothrud (Sanjeevan Hospital)', 'kothrud (Bus stand)',
#        'Karve Road', 'warje', 'Shivaji Nagar (Chaturshringhi)',
#        'Shivaji Nagar', 'Aundh (Botanical Grarden)', 'Aundh',
#        'Someshwarwadi', 'Pashan', 'Baner (Balewadi)',
#        'Mahalunge (Baner) ', 'Yerwada (RTO office)',
#        'yerwada (burning ghat)', 'Dattawadi', 'Vitthalwadi',
#        'Vishrantwadi', 'Pimple Gurav', 'Chinchwad', 'Kasarwadi',
#        'Blank (cuvette)', 'Shivajinagar',
#        'Shivaji nagar (Chaturshringhi)', 'Kothrud (Sanjeevan hospital)',
#        'Kothrud (Karve Road)', 'Warje', 'Kothrud (Bus depot)',
#        'Blank (heat inactivated)', 'Blank Cuvette', 'Shivaji nagar',
#        'Kothrud (Shivaji nagar)', 'Warje ', 'Kothrud',
#        'Someshwarwadi 11.01 am', 'Aundh Botanical garden 11.25 am',
# ...

# %%
df.to_csv('/content/DPP.csv')
